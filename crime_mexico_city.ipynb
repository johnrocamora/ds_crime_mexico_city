# %% [markdown]
# # Análisis Exploratorio de los Meses con Más Sismos en México
#
# ## Juan Rocamora https://www.linkedin.com/in/juanrocamora/
# ## 8-Sep-2021

# %% [markdown]
# #### Cargamos las librerías y configuración preliminar

# %%
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='darkgrid')
sns.set(context='notebook')

# %% [markdown]
# #### Tomamos los datos de www.ssn.unam.mx para México desde 1900 hasta la fecha. El archivo de datos se encuentra en el repositorio de este proyecto. Cargamos el archivo e ignoramos los renglones al principio y al final que contienen descripciones adicionales pero no datos estructurados

# %%
filename_mexico = 'SSNMX_catalogo_19000101_20210908_utc.zip'
df = pd.read_csv(filename_mexico , skiprows=[0,1,2,3,230086,230087,230088,230089,230090,230091,230092], low_memory=False)
df
# Out:
#          Fecha UTC  Hora UTC Magnitud  Latitud  Longitud Profundidad  \
# 0       1900-01-20  06:33:30      7.4    20.00   -105.00        33.0
# 1       1900-05-16  20:12:00      6.9    20.00   -105.00        33.0
# 2       1901-03-05  10:45:00      6.9    25.00   -110.00        33.0
# 3       1901-12-09  02:17:00      7.0    26.00   -110.00        33.0
# 4       1902-01-16  23:19:00      7.0    17.62    -99.72        33.0
# ...            ...       ...      ...      ...       ...         ...
# 230076  2021-09-08  12:20:07      4.5    16.79    -99.85        29.0
# 230077  2021-09-08  13:18:44      4.1    16.76    -99.98        10.0
# 230078  2021-09-08  13:28:09      4.1    16.78    -99.84        10.0
# 230079  2021-09-08  14:48:57      4.0    16.84    -95.23       101.0
# 230080  2021-09-08  20:01:19      4.0    16.65    -99.68        10.0
#
#                          Referencia de localizacion Fecha local Hora local  \
# 0       71 km al NOROESTE de AUTLAN DE NAVARRO, JAL  1900-01-20   00:33:30
# 1       71 km al NOROESTE de AUTLAN DE NAVARRO, JAL  1900-05-16   14:12:00
# 2                  100 km al NORESTE de LA PAZ, BCS  1901-03-05   04:45:00
# 3                      83 km al OESTE de AHOME, SIN  1901-12-08   20:17:00
# 4           21 km al OESTE de ZUMPANGO DEL RIO, GRO  1902-01-16   17:19:00
# ...                                             ...         ...        ...
# 230076           11 km al SURESTE de ACAPULCO, GRO   2021-09-08   07:20:07
# 230077          14 km al SUROESTE de ACAPULCO, GRO   2021-09-08   08:18:44
# 230078           12 km al SURESTE de ACAPULCO, GRO   2021-09-08   08:28:09
# 230079        20 km al OESTE de MATIAS ROMERO, OAX   2021-09-08   09:48:57
# 230080           34 km al SURESTE de ACAPULCO, GRO   2021-09-08   15:01:19
#
#            Estatus
# 0         revisado
# 1         revisado
# 2         revisado
# 3         revisado
# 4         revisado
# ...            ...
# 230076  verificado
# 230077  verificado
# 230078  verificado
# 230079  verificado
# 230080  verificado
#
# [230081 rows x 10 columns]

# %% [markdown]
# #### Empezamos por ignorar los registros con magnitudes 'no calculables'

# %%
df = df[df['Magnitud'] != 'no calculable']
df
# Out:
#          Fecha UTC  Hora UTC Magnitud  Latitud  Longitud Profundidad  \
# 0       1900-01-20  06:33:30      7.4    20.00   -105.00        33.0
# 1       1900-05-16  20:12:00      6.9    20.00   -105.00        33.0
# 2       1901-03-05  10:45:00      6.9    25.00   -110.00        33.0
# 3       1901-12-09  02:17:00      7.0    26.00   -110.00        33.0
# 4       1902-01-16  23:19:00      7.0    17.62    -99.72        33.0
# ...            ...       ...      ...      ...       ...         ...
# 230076  2021-09-08  12:20:07      4.5    16.79    -99.85        29.0
# 230077  2021-09-08  13:18:44      4.1    16.76    -99.98        10.0
# 230078  2021-09-08  13:28:09      4.1    16.78    -99.84        10.0
# 230079  2021-09-08  14:48:57      4.0    16.84    -95.23       101.0
# 230080  2021-09-08  20:01:19      4.0    16.65    -99.68        10.0
#
#                          Referencia de localizacion Fecha local Hora local  \
# 0       71 km al NOROESTE de AUTLAN DE NAVARRO, JAL  1900-01-20   00:33:30
# 1       71 km al NOROESTE de AUTLAN DE NAVARRO, JAL  1900-05-16   14:12:00
# 2                  100 km al NORESTE de LA PAZ, BCS  1901-03-05   04:45:00
# 3                      83 km al OESTE de AHOME, SIN  1901-12-08   20:17:00
# 4           21 km al OESTE de ZUMPANGO DEL RIO, GRO  1902-01-16   17:19:00
# ...                                             ...         ...        ...
# 230076           11 km al SURESTE de ACAPULCO, GRO   2021-09-08   07:20:07
# 230077          14 km al SUROESTE de ACAPULCO, GRO   2021-09-08   08:18:44
# 230078           12 km al SURESTE de ACAPULCO, GRO   2021-09-08   08:28:09
# 230079        20 km al OESTE de MATIAS ROMERO, OAX   2021-09-08   09:48:57
# 230080           34 km al SURESTE de ACAPULCO, GRO   2021-09-08   15:01:19
#
#            Estatus
# 0         revisado
# 1         revisado
# 2         revisado
# 3         revisado
# 4         revisado
# ...            ...
# 230076  verificado
# 230077  verificado
# 230078  verificado
# 230079  verificado
# 230080  verificado
#
# [212432 rows x 10 columns]

# %% [markdown]
# #### Queremos saber los meses con mayor número de sismos de magnitud extrema. Vamos a explorar el grupo de sismos de magnitud  mayor a 7.0 en la escala sismológica de magnitud de momento (común y erróneamente llamada Richter por los medios, la cual ya cayó en desuso)

# %%
df['Magnitud'] = pd.to_numeric(df['Magnitud'])
df = df[df['Magnitud'] > 6]
df
# Out:
#          Fecha UTC  Hora UTC  Magnitud  Latitud  Longitud Profundidad  \
# 0       1900-01-20  06:33:30       7.4  20.0000 -105.0000        33.0
# 1       1900-05-16  20:12:00       6.9  20.0000 -105.0000        33.0
# 2       1901-03-05  10:45:00       6.9  25.0000 -110.0000        33.0
# 3       1901-12-09  02:17:00       7.0  26.0000 -110.0000        33.0
# 4       1902-01-16  23:19:00       7.0  17.6200  -99.7200        33.0
# ...            ...       ...       ...      ...       ...         ...
# 157976  2019-02-01  16:14:12       6.5  14.5818  -92.4807        76.2
# 178553  2019-11-20  04:27:06       6.4  13.7792  -93.3382         9.4
# 196739  2020-05-22  08:46:06       6.2  22.3480 -108.0110         5.0
# 198680  2020-06-23  15:29:03       7.4  15.8033  -96.1337        22.8
# 230010  2021-09-08  01:47:46       7.1  16.7800  -99.9300        10.0
#
#                          Referencia de localizacion Fecha local Hora local  \
# 0       71 km al NOROESTE de AUTLAN DE NAVARRO, JAL  1900-01-20   00:33:30
# 1       71 km al NOROESTE de AUTLAN DE NAVARRO, JAL  1900-05-16   14:12:00
# 2                  100 km al NORESTE de LA PAZ, BCS  1901-03-05   04:45:00
# 3                      83 km al OESTE de AHOME, SIN  1901-12-08   20:17:00
# 4           21 km al OESTE de ZUMPANGO DEL RIO, GRO  1902-01-16   17:19:00
# ...                                             ...         ...        ...
# 157976        37 km al SUROESTE de CD HIDALGO, CHIS  2019-02-01   10:14:12
# 178553       162 km al SUROESTE de CD HIDALGO, CHIS  2019-11-19   22:27:06
# 196739          191 km al SUROESTE de MAZATLAN, SIN  2020-05-22   03:46:06
# 198680              4 km al NORTE de CRUCECITA, OAX  2020-06-23   10:29:03
# 230010          11 km al SUROESTE de ACAPULCO, GRO   2021-09-07   20:47:46
#
#            Estatus
# 0         revisado
# 1         revisado
# 2         revisado
# 3         revisado
# 4         revisado
# ...            ...
# 157976    revisado
# 178553    revisado
# 196739    revisado
# 198680    revisado
# 230010  verificado
#
# [275 rows x 10 columns]

# %% [markdown]
# #### A continuación queremos una columna que nos indique el mes de cada registro para poder analizar los meses. Por comodidad de visualización la pondremos con el nombre del mes en español

# %%
meses = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre']
numero_a_mes = {str(n).zfill(2):meses[n-1] for n in range(1,13)}
df['Mes'] = df['Fecha UTC']
df['Mes'] = df['Mes'].apply(lambda x: x.split('-')[1])
df['Mes'] = df['Mes'].apply(lambda x: numero_a_mes[x])
df
# Out:
#          Fecha UTC  Hora UTC  Magnitud  Latitud  Longitud Profundidad  \
# 0       1900-01-20  06:33:30       7.4  20.0000 -105.0000        33.0
# 1       1900-05-16  20:12:00       6.9  20.0000 -105.0000        33.0
# 2       1901-03-05  10:45:00       6.9  25.0000 -110.0000        33.0
# 3       1901-12-09  02:17:00       7.0  26.0000 -110.0000        33.0
# 4       1902-01-16  23:19:00       7.0  17.6200  -99.7200        33.0
# ...            ...       ...       ...      ...       ...         ...
# 157976  2019-02-01  16:14:12       6.5  14.5818  -92.4807        76.2
# 178553  2019-11-20  04:27:06       6.4  13.7792  -93.3382         9.4
# 196739  2020-05-22  08:46:06       6.2  22.3480 -108.0110         5.0
# 198680  2020-06-23  15:29:03       7.4  15.8033  -96.1337        22.8
# 230010  2021-09-08  01:47:46       7.1  16.7800  -99.9300        10.0
#
#                          Referencia de localizacion Fecha local Hora local  \
# 0       71 km al NOROESTE de AUTLAN DE NAVARRO, JAL  1900-01-20   00:33:30
# 1       71 km al NOROESTE de AUTLAN DE NAVARRO, JAL  1900-05-16   14:12:00
# 2                  100 km al NORESTE de LA PAZ, BCS  1901-03-05   04:45:00
# 3                      83 km al OESTE de AHOME, SIN  1901-12-08   20:17:00
# 4           21 km al OESTE de ZUMPANGO DEL RIO, GRO  1902-01-16   17:19:00
# ...                                             ...         ...        ...
# 157976        37 km al SUROESTE de CD HIDALGO, CHIS  2019-02-01   10:14:12
# 178553       162 km al SUROESTE de CD HIDALGO, CHIS  2019-11-19   22:27:06
# 196739          191 km al SUROESTE de MAZATLAN, SIN  2020-05-22   03:46:06
# 198680              4 km al NORTE de CRUCECITA, OAX  2020-06-23   10:29:03
# 230010          11 km al SUROESTE de ACAPULCO, GRO   2021-09-07   20:47:46
#
#            Estatus         Mes
# 0         revisado       Enero
# 1         revisado        Mayo
# 2         revisado       Marzo
# 3         revisado   Diciembre
# 4         revisado       Enero
# ...            ...         ...
# 157976    revisado     Febrero
# 178553    revisado   Noviembre
# 196739    revisado        Mayo
# 198680    revisado       Junio
# 230010  verificado  Septiembre
#
# [275 rows x 11 columns]

# %%
df['Año'] = df['Fecha UTC']
df['Año'] = df['Año'].apply(lambda x: x.split('-')[0])
df['Año'] = df['Año'].apply(lambda x: pd.to_numeric(x))
df = df[df['Año'] > 1980]
df
# Out:
#          Fecha UTC  Hora UTC  Magnitud  Latitud  Longitud Profundidad  \
# 7877    1981-07-26  05:14:21       6.5  17.7900 -102.0100        21.0
# 8341    1981-10-25  03:22:16       7.3  18.0880 -102.0610        21.0
# 8874    1982-01-02  03:30:41       6.1  15.9300 -100.8800        25.0
# 9342    1982-04-06  19:56:53       6.7  14.2760  -92.0740        45.0
# 9650    1982-06-07  06:52:33       6.9  16.4240  -98.2530         6.0
# ...            ...       ...       ...      ...       ...         ...
# 157976  2019-02-01  16:14:12       6.5  14.5818  -92.4807        76.2
# 178553  2019-11-20  04:27:06       6.4  13.7792  -93.3382         9.4
# 196739  2020-05-22  08:46:06       6.2  22.3480 -108.0110         5.0
# 198680  2020-06-23  15:29:03       7.4  15.8033  -96.1337        22.8
# 230010  2021-09-08  01:47:46       7.1  16.7800  -99.9300        10.0
#
#                           Referencia de localizacion Fecha local Hora local  \
# 7877    28 km al SURESTE de CD LAZARO CARDENAS, MICH  1981-07-25   23:14:21
# 8341        18 km al NORESTE de LAS GUACAMAYAS, MICH  1981-10-24   21:22:16
# 8874                    145 km al SUR de TECPAN, GRO  1982-01-01   21:30:41
# 9342                45 km al SUR de CD HIDALGO, CHIS  1982-04-06   13:56:53
# 9650     23 km al NOROESTE de PINOTEPA NACIONAL, OAX  1982-06-07   00:52:33
# ...                                              ...         ...        ...
# 157976         37 km al SUROESTE de CD HIDALGO, CHIS  2019-02-01   10:14:12
# 178553        162 km al SUROESTE de CD HIDALGO, CHIS  2019-11-19   22:27:06
# 196739           191 km al SUROESTE de MAZATLAN, SIN  2020-05-22   03:46:06
# 198680               4 km al NORTE de CRUCECITA, OAX  2020-06-23   10:29:03
# 230010           11 km al SUROESTE de ACAPULCO, GRO   2021-09-07   20:47:46
#
#            Estatus         Mes   Año
# 7877      revisado       Julio  1981
# 8341      revisado     Octubre  1981
# 8874      revisado       Enero  1982
# 9342      revisado       Abril  1982
# 9650      revisado       Junio  1982
# ...            ...         ...   ...
# 157976    revisado     Febrero  2019
# 178553    revisado   Noviembre  2019
# 196739    revisado        Mayo  2020
# 198680    revisado       Junio  2020
# 230010  verificado  Septiembre  2021
#
# [120 rows x 12 columns]

# %% [markdown]
# #### Analizamos la distribución de los sismos en meses

# %%
df['Mes'].value_counts().plot(kind='bar', colormap='Set2', xlabel='Mes', ylabel='Frecuencia');

# %% [markdown]
# #### En conclusión, septiembre es el mes con más sismos de magnitud mayor a 7.0 en la escala sismológica de magnitud de momento en México

# %% [markdown]
# Nota: Este no es un análisis de causalidad ni una predicción, es un ejemplo del uso de la librería pandas. La interpretación se deja al lector ;)
