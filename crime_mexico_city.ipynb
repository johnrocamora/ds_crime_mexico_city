# %% [markdown]
# # Análisis Exploratorio de Datos de Crímen en CDMX
#
# ## Juan Rocamora https://www.linkedin.com/in/juanrocamora/
# ## 8-Sep-2021

# %% [markdown]
# #### Cargamos las librerías y configuración preliminar

# %%
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'
import seaborn as sns
sns.set(style='darkgrid')
sns.set(context='notebook')

# %% [markdown]
# #### Tomamos los datos de víctimas de carpetas de investigación  de la FGJ para la Ciudad de México (https://datos.cdmx.gob.mx/dataset/victimas-en-carpetas-de-investigacion-fgj). El archivo de datos se encuentra en el repositorio de este proyecto. Cargamos el archivo comprimido.

# %%
filename_mexico = 'victimas_completa_julio_2021.csv.bz2'
df = pd.read_csv(filename_mexico, low_memory=False)
df
# Out:
#         idCarpeta  Año_inicio Mes_inicio FechaInicio  \
# 0         8324429        2019      Enero  04/01/2019
# 1         8324430        2019      Enero  04/01/2019
# 2         8324431        2019      Enero  04/01/2019
# 3         8324435        2019      Enero  04/01/2019
# 4         8324438        2019      Enero  04/01/2019
# ...           ...         ...        ...         ...
# 619180    8985184        2021      Julio  31/07/2021
# 619181    8985185        2021      Julio  31/07/2021
# 619182    8985186        2021      Julio  31/07/2021
# 619183    8985187        2021      Julio  31/07/2021
# 619184    8985188        2021      Julio  31/07/2021
#
#                                                    Delito  \
# 0                                                  FRAUDE
# 1       PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCI...
# 2       ROBO A TRANSEUNTE SALIENDO DEL BANCO CON VIOLE...
# 3       ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VI...
# 4                       ROBO DE MOTOCICLETA SIN VIOLENCIA
# ...                                                   ...
# 619180                       ROBO A NEGOCIO CON VIOLENCIA
# 619181                                  LESIONES CULPOSAS
# 619182  DAÑO EN PROPIEDAD AJENA INTENCIONAL A BIENES I...
# 619183  ALLANAMIENTO DE MORADA, DESPACHO, OFICINA O ES...
# 619184     ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA
#
#                                                 Categoria       Sexo  Edad  \
# 0                                  DELITO DE BAJO IMPACTO  Masculino  62.0
# 1                                  DELITO DE BAJO IMPACTO   Femenino  38.0
# 2       ROBO A CUENTAHABIENTE SALIENDO DEL CAJERO CON ...  Masculino  42.0
# 3                    ROBO DE VEHÍCULO CON Y SIN VIOLENCIA  Masculino  35.0
# 4                    ROBO DE VEHÍCULO CON Y SIN VIOLENCIA  Masculino   NaN
# ...                                                   ...        ...   ...
# 619180                       ROBO A NEGOCIO CON VIOLENCIA        NaN   NaN
# 619181                             DELITO DE BAJO IMPACTO   Femenino   NaN
# 619182                             DELITO DE BAJO IMPACTO        NaN   NaN
# 619183                             DELITO DE BAJO IMPACTO   Femenino   NaN
# 619184  ROBO A TRANSEUNTE EN VÍA PÚBLICA CON Y SIN VIO...  Masculino  27.0
#
#        TipoPersona        CalidadJuridica  ...  Mes_hecho  FechaHecho  \
# 0           FISICA               OFENDIDO  ...     Agosto  29/08/2018
# 1           FISICA  VICTIMA Y DENUNCIANTE  ...  Diciembre  15/12/2018
# 2           FISICA  VICTIMA Y DENUNCIANTE  ...  Diciembre  22/12/2018
# 3           FISICA  VICTIMA Y DENUNCIANTE  ...      Enero  04/01/2019
# 4           FISICA                VICTIMA  ...      Enero  03/01/2019
# ...            ...                    ...  ...        ...         ...
# 619180       MORAL               OFENDIDO  ...      Julio  30/07/2021
# 619181      FISICA                VICTIMA  ...      Julio  30/07/2021
# 619182       MORAL               OFENDIDO  ...      Julio  31/07/2021
# 619183      FISICA  VICTIMA Y DENUNCIANTE  ...       Mayo  26/05/2021
# 619184      FISICA  VICTIMA Y DENUNCIANTE  ...      Julio  31/07/2021
#
#        HoraHecho HoraInicio    AlcaldiaHechos                ColoniaHechos  \
# 0       12:00:00   12:19:00    ALVARO OBREGON                GUADALUPE INN
# 1       15:00:00   12:20:00      AZCAPOTZALCO  VICTORIA DE LAS DEMOCRACIAS
# 2       15:30:00   12:23:00          COYOACAN   COPILCO UNIVERSIDAD ISSSTE
# 3       06:00:00   12:27:00         IZTACALCO           AGRÍCOLA PANTITLAN
# 4       20:00:00   12:35:00        IZTAPALAPA                  PROGRESISTA
# ...          ...        ...               ...                          ...
# 619180  18:22:00   22:57:00        IZTAPALAPA   CONSEJO AGRARISTA MEXICANO
# 619181  15:40:00   22:57:00        CUAUHTEMOC                          NaN
# 619182  14:00:00   23:01:00  GUSTAVO A MADERO             NUEVA ATZACOALCO
# 619183  12:00:00   23:04:00    ALVARO OBREGON           AMPLIACIÓN TEPEACA
# 619184  17:00:00   23:05:00  GUSTAVO A MADERO                   LA PRADERA
#
#                                           Calle_hechos  \
# 0                                       INSUGENTES SUR
# 1                                      AV.  CUATLAHUAC
# 2                                              COPILCO
# 3                                              CALLE 6
# 4                                          UNIVERSIDAD
# ...                                                ...
# 619180                                        PALMILLA
# 619181  NOTIFICACION DEL HOSPITAL NACIONAL HOMEOPÁTICO
# 619182               AVENIDA INGENIERO  EDUARDO MOLINA
# 619183                                  CURUCU  NUM 17
# 619184                             VOLCAN POPOCATEPETL
#
#                                      Calle_hechos2    latitud   longitud
# 0                                              NaN  19.361250 -99.183140
# 1                                              NaN  19.471810 -99.164580
# 2                                              NaN  19.337970 -99.186110
# 3       ENTRE PRIVADA DEL VALLE Y PRIVADA GONZALEZ  19.403270 -99.059830
# 4                                              NaN  19.354800 -99.063240
# ...                                            ...        ...        ...
# 619180                                        PINO  19.320918 -99.056355
# 619181                                         NaN        NaN        NaN
# 619182                                 AVENIDA 314  19.501652 -99.087726
# 619183                                         NaN  19.361710 -99.233410
# 619184                                         NaN  19.475436 -99.065366
#
# [619185 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['idCarpeta', 'Año_inicio', 'Mes_inicio', 'FechaInicio', 'Delito',
#        'Categoria', 'Sexo', 'Edad', 'TipoPersona', 'CalidadJuridica',
#        'competencia', 'Año_hecho', 'Mes_hecho', 'FechaHecho', 'HoraHecho',
#        'HoraInicio', 'AlcaldiaHechos', 'ColoniaHechos', 'Calle_hechos',
#        'Calle_hechos2', 'latitud', 'longitud'],
#       dtype='object')

# %%
list(df['Delito'].values)
# Out:
# ['FRAUDE',
#  'PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCIÓN, ALTERACIÓN O FALSIFICACIÓN DE TÍTULOS AL PORTADOR, DOCUMENTOS DE CRÉDITO PÚBLICOS O VALES DE CANJE',
#  'ROBO A TRANSEUNTE SALIENDO DEL BANCO CON VIOLENCIA',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VIOLENCIA',
#  'ROBO DE MOTOCICLETA SIN VIOLENCIA',
#  'PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCIÓN, ALTERACIÓN O FALSIFICACIÓN DE TÍTULOS AL PORTADOR, DOCUMENTOS DE CRÉDITO PÚBLICOS O VALES DE CANJE',
#  'ROBO A TRANSEUNTE DE CELULAR SIN VIOLENCIA',
#  'VIOLACION',
#  'PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCIÓN, ALTERACIÓN O FALSIFICACIÓN DE TÍTULOS AL PORTADOR, DOCUMENTOS DE CRÉDITO PÚBLICOS O VALES DE CANJE',
#  'OMISION DE AUXILIO O DE CUIDADO',
#  'DESPOJO',
#  'ROBO A PASAJERO A BORDO DE PESERO COLECTIVO CON VIOLENCIA',
#  'PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCIÓN, ALTERACIÓN O FALSIFICACIÓN DE TÍTULOS AL PORTADOR, DOCUMENTOS DE CRÉDITO PÚBLICOS O VALES DE CANJE',
#  'PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCIÓN, ALTERACIÓN O FALSIFICACIÓN DE TÍTULOS AL PORTADOR, DOCUMENTOS DE CRÉDITO PÚBLICOS O VALES DE CANJE',
#  'ROBO DE ACCESORIOS DE AUTO',
#  'ROBO A TRANSEUNTE A BORDO DE TAXI PUBLICO Y PRIVADO SIN VIOLENCIA',
#  'ROBO DE OBJETOS',
#  'ROBO DE OBJETOS',
#  'ABUSO DE CONFIANZA',
#  'ROBO A PASAJERO A BORDO DE TRANSPORTE PÚBLICO CON VIOLENCIA',
#  'VIOLENCIA FAMILIAR',
#  'PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCIÓN, ALTERACIÓN O FALSIFICACIÓN DE TÍTULOS AL PORTADOR, DOCUMENTOS DE CRÉDITO PÚBLICOS O VALES DE CANJE',
#  'ROBO A CASA HABITACION SIN VIOLENCIA',
#  'ROBO A TRANSEUNTE EN RESTAURANT CON VIOLENCIA',
#  'VIOLENCIA FAMILIAR',
#  'ROBO A REPARTIDOR SIN VIOLENCIA',
#  'DELITOS DE ABOGADOS, PATRONOS, LITIGANTES Y ASESORES JURIDICOS',
#  'ROBO A PASAJERO A BORDO DE METRO SIN VIOLENCIA',
#  'AMENAZAS',
#  'LESIONES INTENCIONALES POR ARMA DE FUEGO',
#  'ROBO A TRANSEUNTE DE CELULAR SIN VIOLENCIA',
#  'ROBO A TRANSEUNTE SALIENDO DEL BANCO CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A PASAJERO A BORDO DE METRO SIN VIOLENCIA',
#  'ROBO A TRANSEUNTE CONDUCTOR DE TAXI PUBLICO Y PRIVADO CON VIOLENCIA',
#  'PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCIÓN, ALTERACIÓN O FALSIFICACIÓN DE TÍTULOS AL PORTADOR, DOCUMENTOS DE CRÉDITO PÚBLICOS O VALES DE CANJE',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VIOLENCIA',
#  'DAÑO EN PROPIEDAD AJENA INTENCIONAL',
#  'VIOLENCIA FAMILIAR',
#  'VIOLENCIA FAMILIAR',
#  'ALLANAMIENTO DE MORADA, DESPACHO, OFICINA O ESTABLECIMIENTO MERCANTIL',
#  'ABUSO DE AUTORIDAD Y USO ILEGAL DE LA FUERZA PUBLICA',
#  'ROBO DE MOTOCICLETA SIN VIOLENCIA',
#  'ROBO A REPARTIDOR SIN VIOLENCIA',
#  'VIOLENCIA FAMILIAR',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A TRANSEUNTE DE CELULAR SIN VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'NARCOMENUDEO POSESION SIMPLE',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VIOLENCIA',
#  'VIOLENCIA FAMILIAR',
#  'PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCIÓN, ALTERACIÓN O FALSIFICACIÓN DE TÍTULOS AL PORTADOR, DOCUMENTOS DE CRÉDITO PÚBLICOS O VALES DE CANJE',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCIÓN, ALTERACIÓN O FALSIFICACIÓN DE TÍTULOS AL PORTADOR, DOCUMENTOS DE CRÉDITO PÚBLICOS O VALES DE CANJE',
#  'ROBO DE ACCESORIOS DE AUTO',
#  'ROBO DE OBJETOS',
#  'VIOLENCIA FAMILIAR',
#  'AMENAZAS',
#  'PERDIDA DE LA VIDA POR OTRAS CAUSAS',
#  'ROBO A PASAJERO A BORDO DE METRO SIN VIOLENCIA',
#  'ROBO A PASAJERO A BORDO DE PESERO COLECTIVO CON VIOLENCIA',
#  'ABUSO DE AUTORIDAD Y USO ILEGAL DE LA FUERZA PUBLICA',
#  'ROBO A REPARTIDOR SIN VIOLENCIA',
#  'ROBO A PASAJERO A BORDO DE TRANSPORTE PÚBLICO SIN VIOLENCIA',
#  'VIOLENCIA FAMILIAR',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'DESPOJO',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'ABUSO SEXUAL',
#  'AMENAZAS',
#  'FRAUDE',
#  'ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA',
#  'PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCIÓN, ALTERACIÓN O FALSIFICACIÓN DE TÍTULOS AL PORTADOR, DOCUMENTOS DE CRÉDITO PÚBLICOS O VALES DE CANJE',
#  'DESPOJO',
#  'ROBO DE ACCESORIOS DE AUTO',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'ROBO A PASAJERO A BORDO DE METRO SIN VIOLENCIA',
#  'VIOLENCIA FAMILIAR',
#  'ROBO A TRANSEUNTE DE CELULAR SIN VIOLENCIA',
#  'ROBO DE MOTOCICLETA SIN VIOLENCIA',
#  'ROBO DE MOTOCICLETA SIN VIOLENCIA',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'FRAUDE',
#  'ROBO DE OBJETOS DEL INTERIOR DE UN VEHICULO',
#  'ROBO DE ACCESORIOS DE AUTO',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'ROBO DE OBJETOS',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR CON VIOLENCIA',
#  'ABUSO DE CONFIANZA',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VIOLENCIA',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'ROBO DE OBJETOS',
#  'FRAUDE',
#  'ROBO DE ACCESORIOS DE AUTO',
#  'ABUSO DE CONFIANZA',
#  'ROBO DE ACCESORIOS DE AUTO',
#  'ALLANAMIENTO DE MORADA, DESPACHO, OFICINA O ESTABLECIMIENTO MERCANTIL',
#  'PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCIÓN, ALTERACIÓN O FALSIFICACIÓN DE TÍTULOS AL PORTADOR, DOCUMENTOS DE CRÉDITO PÚBLICOS O VALES DE CANJE',
#  'ROBO A TRANSEUNTE DE CELULAR SIN VIOLENCIA',
#  'VIOLENCIA FAMILIAR',
#  'PRIVACION DE LA LIBERTAD PERSONAL',
#  'ROBO A TRANSEUNTE DE CELULAR SIN VIOLENCIA',
#  'VIOLENCIA FAMILIAR',
#  'AMENAZAS',
#  'ROBO DE OBJETOS',
#  'ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VIOLENCIA',
#  'FRAUDE',
#  'ROBO DE ACCESORIOS DE AUTO',
#  'ROBO DE VEHICULO DE PEDALES',
#  'NARCOMENUDEO POSESION SIMPLE',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'ROBO DE OBJETOS',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA SIN VIOLENCIA',
#  'DAÑO EN PROPIEDAD AJENA CULPOSA',
#  'ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA',
#  'ROBO DE OBJETOS',
#  'DAÑO EN PROPIEDAD AJENA INTENCIONAL',
#  'ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA',
#  'ROBO DE OBJETOS DEL INTERIOR DE UN VEHICULO',
#  'ROBO A PASAJERO A BORDO DE METRO SIN VIOLENCIA',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'ROBO DE OBJETOS',
#  'DESPOJO',
#  'ROBO DE MOTOCICLETA CON VIOLENCIA',
#  'ROBO A PASAJERO / CONDUCTOR DE VEHICULO CON VIOLENCIA',
#  'ROBO A TRANSEUNTE A BORDO DE TAXI PÚBLICO Y PRIVADO CON VIOLENCIA',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VIOLENCIA',
#  'PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCIÓN, ALTERACIÓN O FALSIFICACIÓN DE TÍTULOS AL PORTADOR, DOCUMENTOS DE CRÉDITO PÚBLICOS O VALES DE CANJE',
#  'ROBO A TRANSEUNTE DE CELULAR SIN VIOLENCIA',
#  'ROBO DE OBJETOS',
#  'DAÑO EN PROPIEDAD AJENA INTENCIONAL',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA',
#  'VIOLENCIA FAMILIAR',
#  'DESPOJO',
#  'ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA',
#  'FRAUDE',
#  'PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCIÓN, ALTERACIÓN O FALSIFICACIÓN DE TÍTULOS AL PORTADOR, DOCUMENTOS DE CRÉDITO PÚBLICOS O VALES DE CANJE',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA SIN VIOLENCIA',
#  'AMENAZAS',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'VIOLENCIA FAMILIAR',
#  'AMENAZAS',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'FRAUDE',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR CON VIOLENCIA',
#  'FRAUDE',
#  'ROBO DE VEHICULO DE PEDALES',
#  'VIOLENCIA FAMILIAR',
#  'FRAUDE',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA',
#  'ROBO DE VEHICULO DE PEDALES',
#  'ROBO DE OBJETOS',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO DE OBJETOS',
#  'VIOLENCIA FAMILIAR',
#  'ROBO DE DINERO',
#  'DAÑO EN PROPIEDAD AJENA INTENCIONAL A NEGOCIO',
#  'ROBO DE ACCESORIOS DE AUTO',
#  'VIOLENCIA FAMILIAR',
#  'FRAUDE',
#  'ROBO A PASAJERO / CONDUCTOR DE VEHICULO CON VIOLENCIA',
#  'ROBO A PASAJERO / CONDUCTOR DE VEHICULO CON VIOLENCIA',
#  'DESPOJO',
#  'FRAUDE',
#  'NEGACION DEL SERVICIO PUBLICO',
#  'ABUSO SEXUAL',
#  'DAÑO EN PROPIEDAD AJENA CULPOSA POR TRÁNSITO VEHICULAR A AUTOMOVIL',
#  'VIOLENCIA FAMILIAR',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'ROBO DE MOTOCICLETA CON VIOLENCIA',
#  'ROBO DE OBJETOS DEL INTERIOR DE UN VEHICULO',
#  'PERDIDA DE LA VIDA POR CAIDA',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VIOLENCIA',
#  'DAÑO EN PROPIEDAD AJENA CULPOSA POR TRÁNSITO VEHICULAR A AUTOMOVIL',
#  'VIOLACION',
#  'NARCOMENUDEO POSESION SIMPLE',
#  'TENTATIVA DE ROBO DE VEHICULO',
#  'FRAUDE',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR CON VIOLENCIA',
#  'FRAUDE',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'VIOLENCIA FAMILIAR',
#  'FRAUDE',
#  'HOMICIDIO POR ARMA DE FUEGO',
#  'FRAUDE',
#  'TORTURA',
#  'ROBO DE OBJETOS',
#  'ROBO A REPARTIDOR CON VIOLENCIA',
#  'ABUSO SEXUAL',
#  'DESPOJO',
#  'NEGACION DEL SERVICIO PUBLICO',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'DAÑO EN PROPIEDAD AJENA CULPOSA POR TRÁNSITO VEHICULAR A AUTOMOVIL',
#  'ROBO DE OBJETOS DEL INTERIOR DE UN VEHICULO',
#  'PERDIDA DE LA VIDA POR OTRAS CAUSAS',
#  'ROBO A CASA HABITACION SIN VIOLENCIA',
#  'ACOSO SEXUAL',
#  'NARCOMENUDEO POSESION SIMPLE',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO DE ACCESORIOS DE AUTO',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'DESPOJO',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VIOLENCIA',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'ROBO DE OBJETOS',
#  'VIOLENCIA FAMILIAR',
#  'ROBO DE ACCESORIOS DE AUTO',
#  'VIOLENCIA FAMILIAR',
#  'AMENAZAS',
#  'ROBO A PASAJERO / CONDUCTOR DE VEHICULO CON VIOLENCIA',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA SIN VIOLENCIA',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A CASA HABITACION SIN VIOLENCIA',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'ROBO A PASAJERO A BORDO DE METRO SIN VIOLENCIA',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VIOLENCIA',
#  'ROBO A PASAJERO A BORDO DE PESERO COLECTIVO CON VIOLENCIA',
#  'QUEBRANTAMIENTO DE SELLOS',
#  'NARCOMENUDEO POSESION SIMPLE',
#  'ROBO DE DINERO',
#  'ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO DE OBJETOS',
#  'AMENAZAS',
#  'ROBO DE VEHICULO DE SERVICIO PÚBLICO CON VIOLENCIA',
#  'ROBO DE OBJETOS',
#  'ROBO DE OBJETOS',
#  'ROBO DE OBJETOS',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'ROBO DE OBJETOS',
#  'ROBO DE OBJETOS',
#  'ROBO DE DINERO',
#  'VIOLENCIA FAMILIAR',
#  'VIOLENCIA FAMILIAR',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'ROBO A CASA HABITACION SIN VIOLENCIA',
#  'ROBO A TRANSEUNTE A BORDO DE TAXI PUBLICO Y PRIVADO SIN VIOLENCIA',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'ABUSO DE CONFIANZA',
#  'VIOLENCIA FAMILIAR',
#  'FRAUDE',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'PERDIDA DE LA VIDA POR OTRAS CAUSAS',
#  'PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCIÓN, ALTERACIÓN O FALSIFICACIÓN DE TÍTULOS AL PORTADOR, DOCUMENTOS DE CRÉDITO PÚBLICOS O VALES DE CANJE',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VIOLENCIA',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VIOLENCIA',
#  'ROBO A CASA HABITACION SIN VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'HOMICIDIO CULPOSO POR TRÁNSITO VEHICULAR (COLISION)',
#  'FRAUDE',
#  'OMISION DE AUXILIO O DE CUIDADO',
#  'ROBO A TRANSEUNTE DE CELULAR SIN VIOLENCIA',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'VIOLENCIA FAMILIAR',
#  'ROBO DE ACCESORIOS DE AUTO',
#  'AMENAZAS',
#  'USURPACIÓN DE IDENTIDAD',
#  'AMENAZAS',
#  'PRIVACION DE LA LIBERTAD PERSONAL',
#  'DAÑO EN PROPIEDAD AJENA INTENCIONAL',
#  'ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA',
#  'VIOLENCIA FAMILIAR',
#  'ROBO DE ACCESORIOS DE AUTO',
#  'VIOLENCIA FAMILIAR',
#  'ROBO DE OBJETOS DEL INTERIOR DE UN VEHICULO',
#  'DAÑO EN PROPIEDAD AJENA CULPOSA',
#  'TENTATIVA DE EXTORSION',
#  'LESIONES INTENCIONALES POR GOLPES',
#  'USURPACIÓN DE IDENTIDAD',
#  'NARCOMENUDEO POSESION SIMPLE',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'FRAUDE',
#  'ROBO DE VEHICULO DE PEDALES',
#  'LESIONES CULPOSAS POR TRANSITO VEHICULAR',
#  'LESIONES CULPOSAS POR TRANSITO VEHICULAR EN COLISION',
#  'AMENAZAS',
#  'AMENAZAS',
#  'VIOLACION',
#  'ROBO DE ACCESORIOS DE AUTO',
#  'ROBO A PASAJERO A BORDO DE METROBUS SIN VIOLENCIA',
#  'NARCOMENUDEO POSESION SIMPLE',
#  'ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA',
#  'FALSIFICACION O ALTERACION Y USO INDEBIDO DE DOCUMENTOS',
#  'ROBO A PASAJERO A BORDO DE TRANSPORTE PÚBLICO CON VIOLENCIA',
#  'ROBO DE ACCESORIOS DE AUTO',
#  'ROBO A REPARTIDOR CON VIOLENCIA',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VIOLENCIA',
#  'FRAUDE',
#  'ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A CASA HABITACION CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'VIOLENCIA FAMILIAR',
#  'VIOLENCIA FAMILIAR',
#  'NARCOMENUDEO POSESION SIMPLE',
#  'ROBO A TRANSEUNTE DE CELULAR SIN VIOLENCIA',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA SIN VIOLENCIA',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'VIOLENCIA FAMILIAR',
#  'ROBO A TRANSEUNTE SALIENDO DEL CAJERO CON VIOLENCIA',
#  'ROBO DE OBJETOS DEL INTERIOR DE UN VEHICULO',
#  'VIOLENCIA FAMILIAR',
#  'PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCIÓN, ALTERACIÓN O FALSIFICACIÓN DE TÍTULOS AL PORTADOR, DOCUMENTOS DE CRÉDITO PÚBLICOS O VALES DE CANJE',
#  'FRAUDE',
#  'ROBO DE DINERO',
#  'VIOLENCIA FAMILIAR',
#  'ROBO A PASAJERO A BORDO DE PESERO COLECTIVO CON VIOLENCIA',
#  'NARCOMENUDEO POSESION SIMPLE',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VIOLENCIA',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VIOLENCIA',
#  'FRAUDE',
#  'AMENAZAS',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VIOLENCIA',
#  'FRAUDE',
#  'FRAUDE',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VIOLENCIA',
#  'VIOLENCIA FAMILIAR',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'HOMICIDIO POR ARMA BLANCA',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'AMENAZAS',
#  'ALLANAMIENTO DE MORADA, DESPACHO, OFICINA O ESTABLECIMIENTO MERCANTIL',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO DE OBJETOS',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'ROBO DE OBJETOS',
#  'AMENAZAS',
#  'AMENAZAS',
#  'HOMICIDIO CULPOSO POR TRÁNSITO VEHICULAR (COLISION)',
#  'HOMICIDIO CULPOSO POR TRÁNSITO VEHICULAR (COLISION)',
#  'ROBO DE VEHICULO DE SERVICIO PÚBLICO CON VIOLENCIA',
#  'DAÑO EN PROPIEDAD AJENA INTENCIONAL A AUTOMOVIL',
#  'VIOLACION',
#  'ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA',
#  'ROBO A PASAJERO / CONDUCTOR DE VEHICULO CON VIOLENCIA',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VIOLENCIA',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VIOLENCIA',
#  'ROBO DE OBJETOS',
#  'VIOLENCIA FAMILIAR',
#  'VIOLENCIA FAMILIAR',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'VIOLENCIA FAMILIAR',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCIÓN, ALTERACIÓN O FALSIFICACIÓN DE TÍTULOS AL PORTADOR, DOCUMENTOS DE CRÉDITO PÚBLICOS O VALES DE CANJE',
#  'ROBO A PASAJERO / CONDUCTOR DE VEHICULO CON VIOLENCIA',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'AMENAZAS',
#  'DAÑO EN PROPIEDAD AJENA CULPOSA POR TRÁNSITO VEHICULAR A AUTOMOVIL',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA SIN VIOLENCIA',
#  'PERDIDA DE LA VIDA POR PARO CARDIACO',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'LESIONES CULPOSAS POR TRANSITO VEHICULAR EN COLISION',
#  'ROBO A CASA HABITACION SIN VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A CASA HABITACION SIN VIOLENCIA',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'LESIONES CULPOSAS POR TRANSITO VEHICULAR EN COLISION',
#  'LESIONES CULPOSAS POR TRANSITO VEHICULAR EN COLISION',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO DE MOTOCICLETA SIN VIOLENCIA',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA SIN VIOLENCIA',
#  'ROBO A CASA HABITACION SIN VIOLENCIA',
#  'HOMICIDIO POR ARMA DE FUEGO',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR CON VIOLENCIA',
#  'AMENAZAS',
#  'DAÑO EN PROPIEDAD AJENA INTENCIONAL A CASA HABITACION',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VIOLENCIA',
#  'LESIONES INTENCIONALES POR ARMA DE FUEGO',
#  'LESIONES CULPOSAS POR TRANSITO VEHICULAR EN COLISION',
#  'PERDIDA DE LA VIDA POR OTRAS CAUSAS',
#  'LESIONES CULPOSAS POR CAIDA',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VIOLENCIA',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'LESIONES CULPOSAS POR TRANSITO VEHICULAR EN COLISION',
#  'ROBO DE OBJETOS A ESCUELA',
#  'PERDIDA DE LA VIDA POR OTRAS CAUSAS',
#  'TENTATIVA DE VIOLACION',
#  'VIOLENCIA FAMILIAR',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'OMISION DE AUXILIO O DE CUIDADO',
#  'ROBO DE ACCESORIOS DE AUTO',
#  'ROBO A CASA HABITACION SIN VIOLENCIA',
#  'VIOLENCIA FAMILIAR',
#  'VIOLENCIA FAMILIAR',
#  'ROBO A PASAJERO A BORDO DE TRANSPORTE PÚBLICO SIN VIOLENCIA',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VIOLENCIA',
#  'ROBO A CASA HABITACION SIN VIOLENCIA',
#  'PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCIÓN, ALTERACIÓN O FALSIFICACIÓN DE TÍTULOS AL PORTADOR, DOCUMENTOS DE CRÉDITO PÚBLICOS O VALES DE CANJE',
#  'ROBO A TRANSEUNTE SALIENDO DEL CAJERO CON VIOLENCIA',
#  'AMENAZAS',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'ROBO A PASAJERO / CONDUCTOR DE VEHICULO CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'AMENAZAS',
#  'NARCOMENUDEO POSESION SIMPLE',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'FRAUDE',
#  'ROBO A PASAJERO / CONDUCTOR DE VEHICULO CON VIOLENCIA',
#  'ENCUBRIMIENTO POR FAVORECIMIENTO Y RECEPTACIÓN',
#  'TENTATIVA DE ROBO',
#  'ABUSO SEXUAL',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'ABUSO SEXUAL',
#  'ROBO DE OBJETOS DEL INTERIOR DE UN VEHICULO',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VIOLENCIA',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA SIN VIOLENCIA',
#  'ROBO DE VEHICULO DE SERVICIO PÚBLICO SIN VIOLENCIA',
#  'DAÑO EN PROPIEDAD AJENA CULPOSA POR TRÁNSITO VEHICULAR A AUTOMOVIL',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'AMENAZAS',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'VIOLENCIA FAMILIAR',
#  'VIOLENCIA FAMILIAR',
#  'AMENAZAS',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO DE ACCESORIOS DE AUTO',
#  'PERDIDA DE LA VIDA POR SUICIDIO',
#  'ROBO DE ACCESORIOS DE AUTO',
#  'DAÑO EN PROPIEDAD AJENA INTENCIONAL A BIENES INMUEBLES',
#  'FRAUDE',
#  'ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA',
#  'ROBO DE OBJETOS',
#  'FRAUDE',
#  'ROBO DE VEHICULO DE SERVICIO PÚBLICO SIN VIOLENCIA',
#  'NARCOMENUDEO POSESION SIMPLE',
#  'ROBO DE VEHICULO DE PEDALES',
#  'DAÑO EN PROPIEDAD AJENA CULPOSA',
#  'ROBO DE OBJETOS DEL INTERIOR DE UN VEHICULO',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'FRAUDE',
#  'HOMICIDIO POR ARMA DE FUEGO',
#  'ENCUBRIMIENTO POR FAVORECIMIENTO Y RECEPTACIÓN',
#  'AMENAZAS',
#  'ROBO A TRANSEUNTE A BORDO DE TAXI PÚBLICO Y PRIVADO CON VIOLENCIA',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'ROBO A CASA HABITACION SIN VIOLENCIA',
#  'PERDIDA DE LA VIDA POR OTRAS CAUSAS',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'ROBO A PASAJERO / CONDUCTOR DE VEHICULO CON VIOLENCIA',
#  'PORNOGRAFÍA',
#  'ROBO DE MOTOCICLETA CON VIOLENCIA',
#  'NARCOMENUDEO POSESION SIMPLE',
#  'ROBO DE OBJETOS',
#  'ROBO DE ACCESORIOS DE AUTO',
#  'AMENAZAS',
#  'USURPACIÓN DE IDENTIDAD',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VIOLENCIA',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'AMENAZAS',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'ROBO A CASA HABITACION SIN VIOLENCIA',
#  'LESIONES CULPOSAS POR TRANSITO VEHICULAR',
#  'LESIONES CULPOSAS POR TRANSITO VEHICULAR',
#  'NARCOMENUDEO POSESION SIMPLE',
#  'ROBO DE ACCESORIOS DE AUTO',
#  'PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCIÓN, ALTERACIÓN O FALSIFICACIÓN DE TÍTULOS AL PORTADOR, DOCUMENTOS DE CRÉDITO PÚBLICOS O VALES DE CANJE',
#  'OMISION DE AUXILIO O DE CUIDADO',
#  'ROBO DE ACCESORIOS DE AUTO',
#  'DAÑO EN PROPIEDAD AJENA INTENCIONAL A BIENES INMUEBLES',
#  'ROBO DE OBJETOS A ESCUELA',
#  'ROBO DE VEHICULO DE PEDALES',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO DE VEHICULO DE PEDALES',
#  'ABUSO DE CONFIANZA',
#  'VIOLENCIA FAMILIAR',
#  'VIOLACION',
#  'ABUSO DE CONFIANZA',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR CON VIOLENCIA',
#  'VIOLENCIA FAMILIAR',
#  'ABUSO DE CONFIANZA',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR CON VIOLENCIA',
#  'ROBO DE VEHICULO DE PEDALES',
#  'ABUSO DE CONFIANZA',
#  'ROBO DE OBJETOS DEL INTERIOR DE UN VEHICULO',
#  'PERDIDA DE LA VIDA POR SUICIDIO',
#  'NARCOMENUDEO POSESION SIMPLE',
#  'ROBO A TRANSEUNTE A BORDO DE TAXI PÚBLICO Y PRIVADO CON VIOLENCIA',
#  'VIOLENCIA FAMILIAR',
#  'ROBO DE OBJETOS',
#  'DESPOJO',
#  'LESIONES INTENCIONALES POR ARMA DE FUEGO',
#  'DAÑO EN PROPIEDAD AJENA INTENCIONAL A BIENES INMUEBLES',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'ABUSO DE AUTORIDAD Y USO ILEGAL DE LA FUERZA PUBLICA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO DE MOTOCICLETA SIN VIOLENCIA',
#  'HOMICIDIO POR ARMA DE FUEGO',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'AMENAZAS',
#  'LESIONES INTENCIONALES POR ARMA BLANCA',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'VIOLACION',
#  'HOMICIDIO POR ARMA DE FUEGO',
#  'VIOLENCIA FAMILIAR',
#  'ROBO DE OBJETOS',
#  'ABUSO DE CONFIANZA',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'DAÑO EN PROPIEDAD AJENA INTENCIONAL',
#  'ROBO DE OBJETOS DEL INTERIOR DE UN VEHICULO',
#  'ROBO A REPARTIDOR SIN VIOLENCIA',
#  'HOMICIDIO POR ARMA DE FUEGO',
#  'HOMICIDIO POR GOLPES',
#  'HOMICIDIO POR GOLPES',
#  'PERDIDA DE LA VIDA POR OTRAS CAUSAS',
#  'OMISION DE AUXILIO O DE CUIDADO',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCIÓN, ALTERACIÓN O FALSIFICACIÓN DE TÍTULOS AL PORTADOR, DOCUMENTOS DE CRÉDITO PÚBLICOS O VALES DE CANJE',
#  'VIOLENCIA FAMILIAR',
#  'VIOLENCIA FAMILIAR',
#  'ROBO DE ACCESORIOS DE AUTO',
#  'FRAUDE',
#  'ROBO DE OBJETOS DEL INTERIOR DE UN VEHICULO',
#  'ABUSO SEXUAL',
#  'VIOLACION EQUIPARADA',
#  'DESPOJO',
#  'ROBO DE OBJETOS',
#  'ROBO DE OBJETOS',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO DE OBJETOS',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'ROBO A CASA HABITACION SIN VIOLENCIA',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'ROBO A CASA HABITACION SIN VIOLENCIA',
#  'MALTRATO ANIMAL',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'LESIONES INTENCIONALES POR GOLPES',
#  'LESIONES INTENCIONALES POR GOLPES',
#  'FRAUDE',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'DAÑO EN PROPIEDAD AJENA INTENCIONAL A AUTOMOVIL',
#  'LESIONES CULPOSAS',
#  'ROBO DE MOTOCICLETA CON VIOLENCIA',
#  'VIOLENCIA FAMILIAR',
#  'DAÑO EN PROPIEDAD AJENA CULPOSA POR TRÁNSITO VEHICULAR A BIENES INMUEBLES',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCIÓN, ALTERACIÓN O FALSIFICACIÓN DE TÍTULOS AL PORTADOR, DOCUMENTOS DE CRÉDITO PÚBLICOS O VALES DE CANJE',
#  'ROBO A PASAJERO A BORDO DE METRO SIN VIOLENCIA',
#  'ROBO A CASA HABITACION SIN VIOLENCIA',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'VIOLENCIA FAMILIAR',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA SIN VIOLENCIA',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA SIN VIOLENCIA',
#  'PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCIÓN, ALTERACIÓN O FALSIFICACIÓN DE TÍTULOS AL PORTADOR, DOCUMENTOS DE CRÉDITO PÚBLICOS O VALES DE CANJE',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA SIN VIOLENCIA',
#  'ROBO A CASA HABITACION SIN VIOLENCIA',
#  'VIOLENCIA FAMILIAR',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A REPARTIDOR CON VIOLENCIA',
#  'ROBO DE OBJETOS DEL INTERIOR DE UN VEHICULO',
#  'ALLANAMIENTO DE MORADA, DESPACHO, OFICINA O ESTABLECIMIENTO MERCANTIL',
#  'DAÑO EN PROPIEDAD AJENA INTENCIONAL',
#  'ROBO A PASAJERO / CONDUCTOR DE VEHICULO CON VIOLENCIA',
#  'ROBO A PASAJERO A BORDO DE METRO SIN VIOLENCIA',
#  'ROBO DE OBJETOS',
#  'ROBO DE ANIMALES',
#  'ROBO DE OBJETOS',
#  'VIOLACION TUMULTUARIA',
#  'ROBO DE OBJETOS DEL INTERIOR DE UN VEHICULO',
#  'DESPOJO',
#  'ROBO A REPARTIDOR CON VIOLENCIA',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'VIOLENCIA FAMILIAR',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'VIOLENCIA FAMILIAR',
#  'ROBO DE OBJETOS',
#  'DESPOJO',
#  'ROBO DE OBJETOS',
#  'PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCIÓN, ALTERACIÓN O FALSIFICACIÓN DE TÍTULOS AL PORTADOR, DOCUMENTOS DE CRÉDITO PÚBLICOS O VALES DE CANJE',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA',
#  'LESIONES CULPOSAS POR TRANSITO VEHICULAR EN COLISION',
#  'ABUSO SEXUAL',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA SIN VIOLENCIA',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'VIOLENCIA FAMILIAR',
#  'ROBO A PASAJERO A BORDO DE METRO SIN VIOLENCIA',
#  'ROBO DE OBJETOS A ESCUELA',
#  'ROBO DE OBJETOS',
#  'ROBO A OFICINA PÚBLICA SIN VIOLENCIA',
#  'PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCIÓN, ALTERACIÓN O FALSIFICACIÓN DE TÍTULOS AL PORTADOR, DOCUMENTOS DE CRÉDITO PÚBLICOS O VALES DE CANJE',
#  'AMENAZAS',
#  'ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA',
#  'ROBO DE OBJETOS DEL INTERIOR DE UN VEHICULO',
#  'ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCIÓN, ALTERACIÓN O FALSIFICACIÓN DE TÍTULOS AL PORTADOR, DOCUMENTOS DE CRÉDITO PÚBLICOS O VALES DE CANJE',
#  'ROBO DE OBJETOS',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR CON VIOLENCIA',
#  'ROBO DE OBJETOS',
#  'FRAUDE',
#  'AMENAZAS',
#  'LESIONES INTENCIONALES POR ARMA DE FUEGO',
#  'ROBO A REPARTIDOR CON VIOLENCIA',
#  'AMENAZAS',
#  'ROBO A CASA HABITACION SIN VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'ABUSO DE AUTORIDAD Y USO ILEGAL DE LA FUERZA PUBLICA',
#  'ROBO DE OBJETOS',
#  'FRAUDE',
#  'FRAUDE',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCIÓN, ALTERACIÓN O FALSIFICACIÓN DE TÍTULOS AL PORTADOR, DOCUMENTOS DE CRÉDITO PÚBLICOS O VALES DE CANJE',
#  'ABUSO SEXUAL',
#  'FRAUDE',
#  'VIOLENCIA FAMILIAR',
#  'VIOLENCIA FAMILIAR',
#  'ROBO A CASA HABITACION SIN VIOLENCIA',
#  'ROBO A TRANSEUNTE CONDUCTOR DE TAXI PUBLICO Y PRIVADO CON VIOLENCIA',
#  'ROBO A CASA HABITACION SIN VIOLENCIA',
#  'ROBO A TRANSEUNTE A BORDO DE TAXI PÚBLICO Y PRIVADO CON VIOLENCIA',
#  'PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCIÓN, ALTERACIÓN O FALSIFICACIÓN DE TÍTULOS AL PORTADOR, DOCUMENTOS DE CRÉDITO PÚBLICOS O VALES DE CANJE',
#  'NARCOMENUDEO POSESION SIMPLE',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'AMENAZAS',
#  'ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA',
#  'ROBO DE OBJETOS',
#  'ROBO DE MOTOCICLETA CON VIOLENCIA',
#  'ENCUBRIMIENTO POR FAVORECIMIENTO Y RECEPTACIÓN',
#  'ROBO A CASA HABITACION SIN VIOLENCIA',
#  'ROBO DE OBJETOS DEL INTERIOR DE UN VEHICULO',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'CONTRA EL CUMPLIMIENTO DE LA OBLIGACION ALIMENTARIA',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'ROBO DE OBJETOS',
#  'RETENCIÓN O SUSTRACCIÓN DE MENORES INCAPACES',
#  'ROBO DE MOTOCICLETA CON VIOLENCIA',
#  'ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VIOLENCIA',
#  'DESPOJO',
#  'PERDIDA DE LA VIDA POR OTRAS CAUSAS',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'ROBO DE OBJETOS',
#  'ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA',
#  'ROBO DE ACCESORIOS DE AUTO',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'VIOLENCIA FAMILIAR',
#  'ROBO A REPARTIDOR CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A REPARTIDOR CON VIOLENCIA',
#  'ABUSO DE AUTORIDAD Y USO ILEGAL DE LA FUERZA PUBLICA',
#  'DISCRIMINACION',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'VIOLENCIA FAMILIAR',
#  'ROBO A PASAJERO / CONDUCTOR DE VEHICULO CON VIOLENCIA',
#  'ROBO DE OBJETOS',
#  'ROBO A PASAJERO A BORDO DE PESERO COLECTIVO CON VIOLENCIA',
#  'ROBO A OFICINA PÚBLICA SIN VIOLENCIA',
#  'ROBO DE OBJETOS',
#  'VIOLENCIA FAMILIAR',
#  'VIOLENCIA FAMILIAR',
#  'ROBO A PASAJERO A BORDO DE METRO SIN VIOLENCIA',
#  'ROBO A REPARTIDOR CON VIOLENCIA',
#  'FRAUDE',
#  'ROBO A TRANSEUNTE A BORDO DE TAXI PÚBLICO Y PRIVADO CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'LESIONES INTENCIONALES POR GOLPES',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO DE MOTOCICLETA SIN VIOLENCIA',
#  'ROBO DE OBJETOS',
#  'ROBO A PASAJERO / CONDUCTOR DE VEHICULO CON VIOLENCIA',
#  'ROBO A TRANSEUNTE A BORDO DE TAXI PÚBLICO Y PRIVADO CON VIOLENCIA',
#  'ABUSO DE CONFIANZA',
#  'ROBO DE VEHICULO DE PEDALES',
#  'ROBO DE OBJETOS',
#  'VIOLENCIA FAMILIAR',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCIÓN, ALTERACIÓN O FALSIFICACIÓN DE TÍTULOS AL PORTADOR, DOCUMENTOS DE CRÉDITO PÚBLICOS O VALES DE CANJE',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VIOLENCIA',
#  'ROBO DE OBJETOS DEL INTERIOR DE UN VEHICULO',
#  'DAÑO EN PROPIEDAD AJENA INTENCIONAL',
#  'PRIVACION DE LA LIBERTAD PERSONAL',
#  'AMENAZAS',
#  'LESIONES CULPOSAS POR CAIDA',
#  'ROBO A PASAJERO A BORDO DE TRANSPORTE PÚBLICO CON VIOLENCIA',
#  'ROBO DE OBJETOS DEL INTERIOR DE UN VEHICULO',
#  'AMENAZAS',
#  'ROBO A CASA HABITACION SIN VIOLENCIA',
#  'ROBO A CASA HABITACION SIN VIOLENCIA',
#  'DELITOS AMBIENTALES',
#  'DELITOS AMBIENTALES',
#  'NARCOMENUDEO POSESIÓN CON FINES DE VENTA, COMERCIO Y SUMINISTRO',
#  'AMENAZAS',
#  'AMENAZAS',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'ROBO DE OBJETOS',
#  'ROBO DE MOTOCICLETA SIN VIOLENCIA',
#  'PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCIÓN, ALTERACIÓN O FALSIFICACIÓN DE TÍTULOS AL PORTADOR, DOCUMENTOS DE CRÉDITO PÚBLICOS O VALES DE CANJE',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'ROBO DE VEHICULO DE SERVICIO PÚBLICO SIN VIOLENCIA',
#  'ROBO DE OBJETOS',
#  'ABUSO SEXUAL',
#  'ROBO A CASA HABITACION SIN VIOLENCIA',
#  'ROBO A CASA HABITACION SIN VIOLENCIA',
#  'PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCIÓN, ALTERACIÓN O FALSIFICACIÓN DE TÍTULOS AL PORTADOR, DOCUMENTOS DE CRÉDITO PÚBLICOS O VALES DE CANJE',
#  'ROBO DE ACCESORIOS DE AUTO',
#  'NARCOMENUDEO POSESION SIMPLE',
#  'ROBO DE OBJETOS DEL INTERIOR DE UN VEHICULO',
#  'ROBO DE OBJETOS',
#  'ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA',
#  'DAÑO EN PROPIEDAD AJENA INTENCIONAL A AUTOMOVIL',
#  'AMENAZAS',
#  'ROBO DE OBJETOS A ESCUELA',
#  'RETENCIÓN O SUSTRACCIÓN DE MENORES INCAPACES',
#  'ROBO A CASA HABITACION SIN VIOLENCIA',
#  'VIOLENCIA FAMILIAR',
#  'ALLANAMIENTO DE MORADA, DESPACHO, OFICINA O ESTABLECIMIENTO MERCANTIL',
#  'LESIONES CULPOSAS',
#  'ROBO A PASAJERO A BORDO DE TRANSPORTE PÚBLICO CON VIOLENCIA',
#  'NARCOMENUDEO POSESION SIMPLE',
#  'FRAUDE',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'FRAUDE',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A PASAJERO A BORDO DE METROBUS SIN VIOLENCIA',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VIOLENCIA',
#  'QUEBRANTAMIENTO DE SELLOS',
#  'AMENAZAS',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'QUEBRANTAMIENTO DE SELLOS',
#  'AMENAZAS',
#  'AMENAZAS',
#  'ROBO A REPARTIDOR CON VIOLENCIA',
#  'ROBO A REPARTIDOR CON VIOLENCIA',
#  'ABUSO SEXUAL',
#  'NEGACION DEL SERVICIO PUBLICO',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO DE OBJETOS',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'QUEBRANTAMIENTO DE SELLOS',
#  'LESIONES INTENCIONALES POR GOLPES',
#  'DAÑO EN PROPIEDAD AJENA CULPOSA POR TRÁNSITO VEHICULAR A AUTOMOVIL',
#  'PERSONAS EXTRAVIADAS Y AUSENTES',
#  'FRAUDE',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'ABUSO SEXUAL',
#  'ALLANAMIENTO DE MORADA, DESPACHO, OFICINA O ESTABLECIMIENTO MERCANTIL',
#  'FRAUDE',
#  'VIOLENCIA FAMILIAR',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR CON VIOLENCIA',
#  'PERDIDA DE LA VIDA POR SUICIDIO EN EL METRO',
#  'HOMICIDIO POR ARMA DE FUEGO',
#  'VIOLENCIA FAMILIAR',
#  'ROBO DE VEHICULO DE SERVICIO PÚBLICO CON VIOLENCIA',
#  'PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCIÓN, ALTERACIÓN O FALSIFICACIÓN DE TÍTULOS AL PORTADOR, DOCUMENTOS DE CRÉDITO PÚBLICOS O VALES DE CANJE',
#  'DENUNCIA DE HECHOS',
#  'PRIVACION DE LA LIBERTAD PERSONAL',
#  'VIOLENCIA FAMILIAR',
#  'LESIONES INTENCIONALES POR GOLPES',
#  'VIOLENCIA FAMILIAR',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR CON VIOLENCIA',
#  'USURPACIÓN DE IDENTIDAD',
#  'VIOLENCIA FAMILIAR',
#  'NARCOMENUDEO POSESION SIMPLE',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO DE OBJETOS DEL INTERIOR DE UN VEHICULO',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VIOLENCIA',
#  'DESPOJO',
#  'DESPOJO',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'USURPACIÓN DE IDENTIDAD',
#  'FRAUDE',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'ROBO A PASAJERO A BORDO DE TRANSPORTE PÚBLICO CON VIOLENCIA',
#  'DESPOJO',
#  'ROBO DE OBJETOS',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'AMENAZAS',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'ROBO DE OBJETOS DEL INTERIOR DE UN VEHICULO',
#  'ROBO A PASAJERO / CONDUCTOR DE VEHICULO CON VIOLENCIA',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'ROBO DE DOCUMENTOS',
#  'ROBO DE OBJETOS A ESCUELA',
#  'ROBO DE OBJETOS DEL INTERIOR DE UN VEHICULO',
#  'ROBO DE OBJETOS',
#  'ROBO DE ACCESORIOS DE AUTO',
#  'ROBO DE ACCESORIOS DE AUTO',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'AMENAZAS',
#  'ROBO A TRANSEUNTE DE CELULAR SIN VIOLENCIA',
#  'LA ADMINISTRACION DE JUSTICIA',
#  'DAÑO EN PROPIEDAD AJENA CULPOSA',
#  'VIOLENCIA FAMILIAR',
#  'FRAUDE',
#  'ROBO A TRANSEUNTE DE CELULAR SIN VIOLENCIA',
#  'ROBO DE OBJETOS',
#  'DAÑO EN PROPIEDAD AJENA CULPOSA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A CASA HABITACION SIN VIOLENCIA',
#  'ROBO A PASAJERO A BORDO DE METRO SIN VIOLENCIA',
#  'ROBO A PASAJERO A BORDO DE METRO SIN VIOLENCIA',
#  'OMISION DE AUXILIO O DE CUIDADO',
#  'ROBO DE DOCUMENTOS',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VIOLENCIA',
#  'DESOBEDIENCIA Y RESISTENCIA DE PARTICULARES',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'ROBO A CASA HABITACION SIN VIOLENCIA',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'VIOLENCIA FAMILIAR',
#  'LESIONES INTENCIONALES',
#  'ACOSO SEXUAL',
#  'NARCOMENUDEO POSESION SIMPLE',
#  'ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA',
#  'VIOLENCIA FAMILIAR',
#  'NARCOMENUDEO POSESION SIMPLE',
#  'ROBO DE VEHICULO DE SERVICIO PÚBLICO CON VIOLENCIA',
#  'ROBO DE ACCESORIOS DE AUTO',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'FRAUDE',
#  'ROBO DE ACCESORIOS DE AUTO',
#  'ROBO DE OBJETOS',
#  'ROBO DE OBJETOS',
#  'DESPOJO',
#  'DESPOJO',
#  'AMENAZAS',
#  'AMENAZAS',
#  'ROBO A PASAJERO A BORDO DE TRANSPORTE PÚBLICO CON VIOLENCIA',
#  'ROBO DE OBJETOS',
#  'VIOLENCIA FAMILIAR',
#  'LESIONES INTENCIONALES POR GOLPES',
#  'PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCIÓN, ALTERACIÓN O FALSIFICACIÓN DE TÍTULOS AL PORTADOR, DOCUMENTOS DE CRÉDITO PÚBLICOS O VALES DE CANJE',
#  'LA ADMINISTRACION DE JUSTICIA',
#  'ROBO DE DOCUMENTOS',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'ROBO A CASA HABITACION SIN VIOLENCIA',
#  'ROBO DE OBJETOS',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VIOLENCIA',
#  'DAÑO EN PROPIEDAD AJENA CULPOSA POR TRÁNSITO VEHICULAR A BIENES INMUEBLES',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'FRAUDE',
#  'LESIONES CULPOSAS POR TRANSITO VEHICULAR EN COLISION',
#  'LESIONES CULPOSAS POR TRANSITO VEHICULAR EN COLISION',
#  'ABUSO DE AUTORIDAD Y USO ILEGAL DE LA FUERZA PUBLICA',
#  'VIOLENCIA FAMILIAR',
#  'VIOLENCIA FAMILIAR',
#  'VIOLENCIA FAMILIAR',
#  'LESIONES INTENCIONALES POR GOLPES',
#  'ROBO A CASA HABITACION SIN VIOLENCIA',
#  'ROBO A PASAJERO A BORDO DE METRO SIN VIOLENCIA',
#  'LESIONES INTENCIONALES POR GOLPES',
#  'ROBO DE OBJETOS',
#  'VIOLENCIA FAMILIAR',
#  'VIOLENCIA FAMILIAR',
#  'ROBO A TRANSEUNTE DE CELULAR SIN VIOLENCIA',
#  'ROBO A PASAJERO A BORDO DE METRO SIN VIOLENCIA',
#  'VIOLENCIA FAMILIAR',
#  'DAÑO EN PROPIEDAD AJENA INTENCIONAL',
#  'ROBO A REPARTIDOR CON VIOLENCIA',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'VIOLENCIA FAMILIAR',
#  'PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCIÓN, ALTERACIÓN O FALSIFICACIÓN DE TÍTULOS AL PORTADOR, DOCUMENTOS DE CRÉDITO PÚBLICOS O VALES DE CANJE',
#  'VIOLENCIA FAMILIAR',
#  'ROBO DE OBJETOS',
#  'ROBO DE OBJETOS DEL INTERIOR DE UN VEHICULO',
#  'DAÑO EN PROPIEDAD AJENA CULPOSA POR TRÁNSITO VEHICULAR A AUTOMOVIL',
#  'NARCOMENUDEO POSESION SIMPLE',
#  'ROBO A PASAJERO / CONDUCTOR DE VEHICULO CON VIOLENCIA',
#  'ROBO DE ANIMALES',
#  'ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA',
#  'DAÑO EN PROPIEDAD AJENA INTENCIONAL',
#  'FRAUDE',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'VIOLENCIA FAMILIAR',
#  'VIOLENCIA FAMILIAR',
#  'ROBO A TRANSEUNTE SALIENDO DEL BANCO CON VIOLENCIA',
#  'VIOLENCIA FAMILIAR',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR CON VIOLENCIA',
#  'NARCOMENUDEO POSESION SIMPLE',
#  'DESPOJO',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'ROBO DE OBJETOS DEL INTERIOR DE UN VEHICULO',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VIOLENCIA',
#  'AMENAZAS',
#  'LESIONES INTENCIONALES POR GOLPES',
#  'LESIONES INTENCIONALES POR GOLPES',
#  'USURPACIÓN DE IDENTIDAD',
#  'ALLANAMIENTO DE MORADA, DESPACHO, OFICINA O ESTABLECIMIENTO MERCANTIL',
#  'ROBO DE OBJETOS DEL INTERIOR DE UN VEHICULO',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'ROBO DE OBJETOS DEL INTERIOR DE UN VEHICULO',
#  'ROBO A PASAJERO A BORDO DE METRO SIN VIOLENCIA',
#  'TENTATIVA DE EXTORSION',
#  'NARCOMENUDEO POSESIÓN CON FINES DE VENTA, COMERCIO Y SUMINISTRO',
#  'LESIONES INTENCIONALES POR GOLPES',
#  'USURPACIÓN DE IDENTIDAD',
#  'ROBO DE MOTOCICLETA SIN VIOLENCIA',
#  'ROBO DE OBJETOS',
#  'ROBO A PASAJERO A BORDO DE METROBUS SIN VIOLENCIA',
#  'ROBO A NEGOCIO Y VEHICULO CON VIOLENCIA',
#  'ROBO A NEGOCIO Y VEHICULO CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ABUSO SEXUAL',
#  'ABUSO DE CONFIANZA',
#  'AMENAZAS',
#  'DAÑO EN PROPIEDAD AJENA INTENCIONAL',
#  'ROBO A TRANSEUNTE SALIENDO DEL BANCO CON VIOLENCIA',
#  'ROBO DE ACCESORIOS DE AUTO',
#  'VIOLENCIA FAMILIAR',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'ENCUBRIMIENTO POR FAVORECIMIENTO Y RECEPTACIÓN',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A NEGOCIO CON VIOLENCIA',
#  'ROBO A TRANSEUNTE EN VIA PUBLICA CON VIOLENCIA',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'ROBO A REPARTIDOR CON VIOLENCIA',
#  'ROBO A PASAJERO A BORDO DE METRO SIN VIOLENCIA',
#  'ROBO DE PLACA DE AUTOMOVIL',
#  'ROBO A NEGOCIO Y VEHICULO CON VIOLENCIA',
#  'ROBO A NEGOCIO Y VEHICULO CON VIOLENCIA',
#  'ROBO A NEGOCIO Y VEHICULO CON VIOLENCIA',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCIÓN, ALTERACIÓN O FALSIFICACIÓN DE TÍTULOS AL PORTADOR, DOCUMENTOS DE CRÉDITO PÚBLICOS O VALES DE CANJE',
#  'DAÑO EN PROPIEDAD AJENA INTENCIONAL A CASA HABITACION',
#  'LA ADMINISTRACION DE JUSTICIA',
#  'ROBO DE VEHICULO DE SERVICIO PARTICULAR CON VIOLENCIA',
#  'POSESION DE VEHICULO ROBADO',
#  'ROBO DE ACCESORIOS DE AUTO',
#  'ROBO A TRANSEUNTE DE CELULAR CON VIOLENCIA',
#  'ROBO A NEGOCIO SIN VIOLENCIA',
#  'ROBO A CASA HABITACION SIN VIOLENCIA',
#  'DAÑO EN PROPIEDAD AJENA INTENCIONAL',
#  'ABUSO DE CONFIANZA',
#  'ROBO DE VEHICULO DE SERVICIO PÚBLICO CON VIOLENCIA',
#  'ROBO DE OBJETOS',
#  'DAÑO EN PROPIEDAD AJENA INTENCIONAL',
#  'LESIONES CULPOSAS POR TRANSITO VEHICULAR EN COLISION',
#  'ABUSO DE CONFIANZA',
#  ...]

# %% [markdown]
# #### Empezamos por ignorar los registros con magnitudes 'no calculables'

# %%
df.iloc[2000]
# Out:
# idCarpeta                               8330594
# Año_inicio                                 2019
# Mes_inicio                                Enero
# FechaInicio                          12/01/2019
# Delito             ROBO A NEGOCIO CON VIOLENCIA
# Categoria          ROBO A NEGOCIO CON VIOLENCIA
# Sexo                                        NaN
# Edad                                        NaN
# TipoPersona                               MORAL
# CalidadJuridica                        OFENDIDO
# competencia                         FUERO COMUN
# Año_hecho                                  2018
# Mes_hecho                             Noviembre
# FechaHecho                           23/11/2018
# HoraHecho                              21:00:00
# HoraInicio                             15:38:00
# AlcaldiaHechos                          TLAHUAC
# ColoniaHechos                   BARRIO SANTIAGO
# Calle_hechos                         EJE 10 SUR
# Calle_hechos2                               NaN
# latitud                                 19.3126
# longitud                               -98.9637
# Name: 2000, dtype: object

# %%
df = df.dropna()
latitude = df['latitud'].to_list()
longitude = df['longitud'].to_list()
latitude = latitude[0:2000]
longitude = longitude[0:2000]

# %%
import matplotlib.pyplot as plt
import mplleaflet

# longitude = [-99.17756,-99.17256]
# latitude = [19.44290, 19.44690]

plt.plot(longitude, latitude, 'rx') # Draw red squares

mplleaflet.display()
# Out:
# /home/isla/.local/lib/python3.8/site-packages/IPython/core/display.py:717: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe src="data:text/html;base64,..." width="100%" height="240"></iframe>
